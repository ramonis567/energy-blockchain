# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
num_ini = 0

# %%
import matplotlib.pyplot as plt

dados = np.random.normal(loc=3, scale=1, size=24*4)
plt.hist(dados, bins=30, density=True, alpha=0.6, color='b')
plt.xlabel('Valor')
plt.ylabel('Frequência')
plt.title('Distribuição Normal (média=50, desvio=10)')
plt.show()
